# %% [markdown]
# # Lab 0: Data Readiness
#
# Complete these tasks to verify your setup.

# %% [markdown]
# ## Task 1: Load and Preview Data

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/GSIS-DS/data-science-ai-global-decision-making/main/data/sample/global_indicators_sample.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ## Task 2: Verify Required Packages

# %%
import matplotlib
import seaborn
import sklearn
print("All packages imported successfully!")

# %% [markdown]
# ## Task 3: Save a Test Plot

# %%
import matplotlib.pyplot as plt
df.groupby('region')['gdp_growth'].mean().plot(kind='bar')
plt.title('Test Plot')
plt.show()

# %% [markdown]
# If all cells run without errors, your environment is ready!
