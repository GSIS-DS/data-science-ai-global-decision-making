# %% [markdown]
# # Lab 1: Data Wrangling
#
# Tasks: Clean and transform the sample dataset.

# %% [markdown]
# ## Task 1: Check and Handle Missing Values

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/GSIS-DS-Fall-2026/data-science-ai-global-decision-making/main/data/sample/global_indicators_sample.csv"
df = pd.read_csv(url)
df.isnull().sum()

# %% [markdown]
# ## Task 2: Create a New Variable

# %%
# Create trade_balance column
# df['trade_balance'] = ...
# Show result
df.head()

# %% [markdown]
# ## Task 3: Filter and Summarize

# %%
# Average inflation by region
# df.groupby('region')['inflation'].mean()
