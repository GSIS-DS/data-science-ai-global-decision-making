# %% [markdown]
# # Lab 4: Bounded Agent Workflow
#
# Learn to structure reliable analytical workflows.

# %% [markdown]
# ## Bounded Agent Workflow Template
#
# Every analytical workflow should follow:
# 1. **Question**: Clearly defined problem
# 2. **Data/Tools**: Specified inputs and methods
# 3. **Steps**: Transparent analytical process
# 4. **Draft Output**: Initial findings
# 5. **Verification**: Check against data/sources
# 6. **Human Decision**: Final judgment and approval

# %%
# Define your question
question = "Which countries show the strongest correlation between trade openness and GDP growth?"
print(f"Question: {question}")

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/GSIS-DS/data-science-ai-global-decision-making/main/data/sample/global_indicators_sample.csv"
df = pd.read_csv(url)

# Your analytical steps here
