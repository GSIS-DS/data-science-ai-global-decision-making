# %% [markdown]
# # Lab 2: Visualization

# %% [markdown]
# ## Task 1: Create a Bar Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/GSIS-DS-Fall-2026/data-science-ai-global-decision-making/main/data/sample/global_indicators_sample.csv"
df = pd.read_csv(url)

# %% [markdown]
# ## Task 2: Improve Chart Design

# %%
# Add title, labels, and source to your chart
plt.figure(figsize=(10, 6))
# Your code here
