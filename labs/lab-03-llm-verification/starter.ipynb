# %% [markdown]
# # Lab 3: LLM Verification
#
# This lab focuses on using AI tools responsibly with proper verification.

# %% [markdown]
# ## AI Use Statement Template
#
# Include this with any assignment using AI tools.

# %%
# You may use AI tools for:
# - Explaining concepts
# - Debugging code
# - Suggesting structure
# - Improving wording
# - Brainstorming questions
#
# But you must:
# - Disclose use
# - Verify output against data
# - Understand what you submit

# %% [markdown]
# ## Task: Verify AI-Generated Code
#
# If an AI suggests code, always verify it works correctly with your data.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/GSIS-DS-Fall-2026/data-science-ai-global-decision-making/main/data/sample/global_indicators_sample.csv"
df = pd.read_csv(url)

# Test and verify any AI-suggested code here
