# %% [markdown]
# # Reproducible Notebook Example
#
# This notebook demonstrates good structure and reproducibility practices.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load Data

# %%
url = "https://raw.githubusercontent.com/GSIS-DS-Fall-2026/data-science-ai-global-decision-making/main/data/sample/global_indicators_sample.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ## Analysis

# %%
# Reproducible steps with clear comments
regional_summary = df.groupby('region')[['gdp_growth', 'inflation', 'co2_per_capita']].mean()
